# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('mpg.csv')
df.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model_year  \
# 0  18.0          8         307.0        130    3504          12.0          70
# 1  15.0          8         350.0        165    3693          11.5          70
# 2  18.0          8         318.0        150    3436          11.0          70
# 3  16.0          8         304.0        150    3433          12.0          70
# 4  17.0          8         302.0        140    3449          10.5          70
#
#    origin                       name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
df['model_year'].nunique()
# Out:
# 13

# %%
df.groupby('model_year')

# %%
df.groupby('model_year').mean(numeric_only=True)
# Out:
#                   mpg  cylinders  displacement       weight  acceleration  \
# model_year
# 70          17.689655   6.758621    281.413793  3372.793103     12.948276
# 71          21.250000   5.571429    209.750000  2995.428571     15.142857
# 72          18.714286   5.821429    218.375000  3237.714286     15.125000
# 73          17.100000   6.375000    256.875000  3419.025000     14.312500
# 74          22.703704   5.259259    171.740741  2877.925926     16.203704
# 75          20.266667   5.600000    205.533333  3176.800000     16.050000
# 76          21.573529   5.647059    197.794118  3078.735294     15.941176
# 77          23.375000   5.464286    191.392857  2997.357143     15.435714
# 78          24.061111   5.361111    177.805556  2861.805556     15.805556
# 79          25.093103   5.827586    206.689655  3055.344828     15.813793
# 80          33.696552   4.137931    115.827586  2436.655172     16.934483
# ...

# %%
df.groupby('model_year')[['mpg', 'displacement']].mean(numeric_only=True)
# Out:
#                   mpg  displacement
# model_year
# 70          17.689655    281.413793
# 71          21.250000    209.750000
# 72          18.714286    218.375000
# 73          17.100000    256.875000
# 74          22.703704    171.740741
# 75          20.266667    205.533333
# 76          21.573529    197.794118
# 77          23.375000    191.392857
# 78          24.061111    177.805556
# 79          25.093103    206.689655
# 80          33.696552    115.827586
# 81          30.334483    135.310345
# 82          31.709677    128.870968

# %%
df.groupby(['model_year', 'mpg']).mean(numeric_only=True)
# Out:
#                  cylinders  displacement  weight  acceleration  origin
# model_year mpg
# 70         9.0         8.0        304.00  4732.0        18.500     1.0
#            10.0        8.0        333.50  4495.5        14.500     1.0
#            11.0        8.0        318.00  4382.0        13.500     1.0
#            14.0        8.0        428.80  3957.2         9.100     1.0
#            15.0        8.0        390.40  3841.6         9.900     1.0
# ...                    ...           ...     ...           ...     ...
# 82         34.0        4.0        110.00  2320.0        17.450     2.0
#            36.0        4.0        113.00  2168.0        14.920     2.0
#            37.0        4.0         91.00  2025.0        18.200     3.0
#            38.0        4.5        137.25  2275.0        15.725     2.0
#            44.0        4.0         97.00  2130.0        24.600     2.0
#
# [264 rows x 5 columns]

# %%
df.columns
# Out:
# Index(['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'model_year', 'origin', 'name'],
#       dtype='object')

# %%
df.groupby(['model_year', 'mpg']).mean(numeric_only=True).index
# Out:
# MultiIndex([(70,  9.0),
#             (70, 10.0),
#             (70, 11.0),
#             (70, 14.0),
#             (70, 15.0),
#             (70, 16.0),
#             (70, 17.0),
#             (70, 18.0),
#             (70, 21.0),
#             (70, 22.0),
#             ...
#             (82, 27.0),
#             (82, 28.0),
#             (82, 29.0),
#             (82, 31.0),
#             (82, 32.0),
#             (82, 34.0),
#             (82, 36.0),
#             (82, 37.0),
#             (82, 38.0),
#             (82, 44.0)],
#            names=['model_year', 'mpg'], length=264)

# %%
multi = df.groupby(['model_year', 'mpg']).mean(numeric_only=True)
multi.head()
# Out:
#                  cylinders  displacement  weight  acceleration  origin
# model_year mpg
# 70         9.0         8.0         304.0  4732.0          18.5     1.0
#            10.0        8.0         333.5  4495.5          14.5     1.0
#            11.0        8.0         318.0  4382.0          13.5     1.0
#            14.0        8.0         428.8  3957.2           9.1     1.0
#            15.0        8.0         390.4  3841.6           9.9     1.0

# %%
multi.loc[70]
# Out:
#       cylinders  displacement  weight  acceleration  origin
# mpg
# 9.0    8.000000    304.000000  4732.0     18.500000     1.0
# 10.0   8.000000    333.500000  4495.5     14.500000     1.0
# 11.0   8.000000    318.000000  4382.0     13.500000     1.0
# 14.0   8.000000    428.800000  3957.2      9.100000     1.0
# 15.0   8.000000    390.400000  3841.6      9.900000     1.0
# 16.0   8.000000    304.000000  3433.0     12.000000     1.0
# 17.0   8.000000    302.000000  3449.0     10.500000     1.0
# 18.0   7.333333    274.666667  3238.0     12.833333     1.0
# 21.0   6.000000    199.500000  2617.5     15.500000     1.0
# 22.0   6.000000    198.000000  2833.0     15.500000     1.0
# 24.0   4.000000    110.000000  2401.0     14.750000     2.5
# 25.0   4.000000    107.000000  2523.5     17.500000     2.0
# 26.0   4.000000    109.000000  2034.5     16.500000     2.0
# 27.0   4.000000     97.000000  2130.0     14.500000     3.0

# %%
multi.loc[[70, 82]]
# Out:
#                  cylinders  displacement       weight  acceleration    origin
# model_year mpg
# 70         9.0    8.000000    304.000000  4732.000000     18.500000  1.000000
#            10.0   8.000000    333.500000  4495.500000     14.500000  1.000000
#            11.0   8.000000    318.000000  4382.000000     13.500000  1.000000
#            14.0   8.000000    428.800000  3957.200000      9.100000  1.000000
#            15.0   8.000000    390.400000  3841.600000      9.900000  1.000000
#            16.0   8.000000    304.000000  3433.000000     12.000000  1.000000
#            17.0   8.000000    302.000000  3449.000000     10.500000  1.000000
#            18.0   7.333333    274.666667  3238.000000     12.833333  1.000000
#            21.0   6.000000    199.500000  2617.500000     15.500000  1.000000
#            22.0   6.000000    198.000000  2833.000000     15.500000  1.000000
#            24.0   4.000000    110.000000  2401.000000     14.750000  2.500000
# ...

# %%
multi.index
# Out:
# MultiIndex([(70,  9.0),
#             (70, 10.0),
#             (70, 11.0),
#             (70, 14.0),
#             (70, 15.0),
#             (70, 16.0),
#             (70, 17.0),
#             (70, 18.0),
#             (70, 21.0),
#             (70, 22.0),
#             ...
#             (82, 27.0),
#             (82, 28.0),
#             (82, 29.0),
#             (82, 31.0),
#             (82, 32.0),
#             (82, 34.0),
#             (82, 36.0),
#             (82, 37.0),
#             (82, 38.0),
#             (82, 44.0)],
#            names=['model_year', 'mpg'], length=264)

# %%
multi.loc[(70, 10.0), 'cylinders']
# Out:
# 8.0

# %%
multi
# Out:
#                  cylinders  displacement  weight  acceleration  origin
# model_year mpg
# 70         9.0         8.0        304.00  4732.0        18.500     1.0
#            10.0        8.0        333.50  4495.5        14.500     1.0
#            11.0        8.0        318.00  4382.0        13.500     1.0
#            14.0        8.0        428.80  3957.2         9.100     1.0
#            15.0        8.0        390.40  3841.6         9.900     1.0
# ...                    ...           ...     ...           ...     ...
# 82         34.0        4.0        110.00  2320.0        17.450     2.0
#            36.0        4.0        113.00  2168.0        14.920     2.0
#            37.0        4.0         91.00  2025.0        18.200     3.0
#            38.0        4.5        137.25  2275.0        15.725     2.0
#            44.0        4.0         97.00  2130.0        24.600     2.0
#
# [264 rows x 5 columns]

# %%
multi.swaplevel()
# Out:
#                  cylinders  displacement  weight  acceleration  origin
# mpg  model_year
# 9.0  70                8.0        304.00  4732.0        18.500     1.0
# 10.0 70                8.0        333.50  4495.5        14.500     1.0
# 11.0 70                8.0        318.00  4382.0        13.500     1.0
# 14.0 70                8.0        428.80  3957.2         9.100     1.0
# 15.0 70                8.0        390.40  3841.6         9.900     1.0
# ...                    ...           ...     ...           ...     ...
# 34.0 82                4.0        110.00  2320.0        17.450     2.0
# 36.0 82                4.0        113.00  2168.0        14.920     2.0
# 37.0 82                4.0         91.00  2025.0        18.200     3.0
# 38.0 82                4.5        137.25  2275.0        15.725     2.0
# 44.0 82                4.0         97.00  2130.0        24.600     2.0
#
# [264 rows x 5 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    398 non-null    object
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model_year    398 non-null    int64
#  7   origin        398 non-null    int64
#  8   name          398 non-null    object
# dtypes: float64(3), int64(4), object(2)
# memory usage: 28.1+ KB

# %%
df.select_dtypes(include=['number']).agg(['std', 'mean'])
# Out:
#             mpg  cylinders  displacement       weight  acceleration  \
# std    7.815984   1.701004    104.269838   846.841774      2.757689
# mean  23.514573   5.454774    193.425879  2970.424623     15.568090
#
#       model_year    origin
# std     3.697627  0.802055
# mean   76.010050  1.572864

# %%
df.select_dtypes(include=['number']).agg({'mpg': ['std', 'mean'], 'cylinders': 'sum'})
# Out:
#             mpg  cylinders
# std    7.815984        NaN
# mean  23.514573        NaN
# sum         NaN     2171.0

# %%
df.groupby('origin').agg({'mpg': ['std', 'mean'], 'cylinders': 'sum'})
# Out:
#              mpg            cylinders
#              std       mean       sum
# origin
# 1       6.402892  20.083534      1556
# 2       6.723930  27.891429       291
# 3       6.090048  30.450633       324
